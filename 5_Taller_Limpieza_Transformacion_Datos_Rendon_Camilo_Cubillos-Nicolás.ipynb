# %% [markdown]
# # **Inteligencia Artificial con Aplicaciones en Economía I**
#
# - 👩‍🏫 **Profesora:** [Lina María Castro](https://www.linkedin.com/in/lina-maria-castro)
# - 📧 **Email:** [lmcastroco@gmail.com](mailto:lmcastroco@gmail.com)
# - 🎓 **Universidad:** Universidad Externado de Colombia - Facultad de Economía

# %% [markdown]
# # **Taller Limpieza y transformación de datos**🧹

# %% [markdown]
# **IMPORTANTE**: Guarda una copia de este notebook en tu Google Drive o computador.

# %% [markdown]
# **Taller en grupos de 3 o parejas.**

# %% [markdown]
# **Nombres estudiantes:**
#
# - Camilo Rendón C.
# - Nicolás Cubillos R.
# -

# %% [markdown]
# **Forma de entrega:**
#
# - Nombrar el archivo de la siguiente forma:“Taller_Limpieza_nombres_y_appellidos.ipynb”.
# - Suba el Jupyter Notebook a su cuenta en Github y envíe el link en el siguiente Forms: https://forms.office.com/r/6GZ89uiLNC.
#
# **IMPORTANTE:** No se recibirán talleres en Google Colab, el notebook debe estar subido en Github.

# %% [markdown]
# **Plazo de entrega:**
#
# 19 de marzo de 2026, máximo a las 11:59 p.m. Tenga en cuenta que luego de esa hora el formulario en forms se cierra. El Jupupyter Notebook también debe quedar subido en Github antes de esa hora.

# %% [markdown]
# **Instrucciones Generales:**
#
# Completa el código en las celdas marcadas con `### TU CÓDIGO AQUÍ ###`. Puedes añadir más celdas si lo requieres.

# %% [markdown]
# Utilice la base de la GEIH de julio a diciembre de 2025, la cual se encuentra en https://drive.google.com/drive/folders/1Th4TWdsOahAAvBUKxixFhaELC_KPsl3y?usp=sharing. Tenga en cuenta sep="," y encoding='latin1'. Las variables 'DPTO' y 'RAMA4D_R4' deben ser cargadas como string.

# %% [markdown]
# # Ejercicio 1: Importar librerías y cargar datos

# %% [markdown]
# 1.	Importe todas las librerías que vaya a utilizar.

# %%
import os
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 2.	Mejore la visualización de los dataframes como se ha visto en clase.

# %%
# Que muestre todas las columnas
pd.options.display.max_columns = None
# En los dataframes, mostrar los float con dos decimales
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# 3.	Conéctese a su Google Drive y establezca la ruta del dataset.

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Bases'

# %%
os.chdir(path)

# %% [markdown]
# 4.	Cargue los datos en el notebook. Llame al dataframe 'df_geih'

# %%
df_geih = pd.read_csv('/content/drive/MyDrive/Bases/GEIH_2025_Jul_Dic_Consolidado.csv', encoding='latin1')

# %% [markdown]
# 5. Obtenga las dimensiones de la base

# %%
df_geih.shape
# Out:
# (409127, 314)

# %% [markdown]
# # Ejercicio 2:  Seleccionar y renombrar columnas

# %% [markdown]
# La GEIH contiene cientos de variables. Para nuestro análisis del mercado laboral, nos enfocaremos en un subconjunto.
#
# Adicionalmente, los nombres de las columnas en la GEIH son códigos. Para hacer el análisis más intuitivo, vamos a renombrarlas.

# %% [markdown]
# 1. Crea un nuevo DataFrame llamado `df_empleo` que contenga únicamente las columnas que están en la lista `columnas_interes`.

# %%
columnas_interes = ['DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'MES', 'CLASE', 'DPTO', 'FEX_C18', 'PT', 'P3271', 'P6040', 'P6080', 'P3043', 'OCI',
                    'P6430', 'RAMA4D_R4', 'INGLABO', 'DESCRIPCION_CIIU', 'NOMBRE_DPTO']

# %%
df_empleo = df_geih[columnas_interes]
df_empleo
# Out:
#         DIRECTORIO  SECUENCIA_P  ORDEN  MES  CLASE  DPTO  FEX_C18  PT  P3271  \
# 0          8283143            1      1    7      2     8    27.75   1      1
# 1          8283143            1      2    7      2     8    27.75   1      2
# 2          8283145            1      1    7      2     8    59.11   1      1
# 3          8283145            1      2    7      2     8    59.11   1      2
# 4          8283145            1      3    7      2     8    59.11   1      1
# ...            ...          ...    ...  ...    ...   ...      ...  ..    ...
# 409122     8473907            1      1   12      2    73   378.31   1      2
# 409123     8473908            1      1   12      1    54   534.55   1      1
# 409124     8473908            1      2   12      1    54   534.55   1      2
# 409125     8473908            1      3   12      1    54   534.55   1      2
# 409126     8473908            1      4   12      1    54   534.55   1      2
#
#         P6040  P6080  P3043  OCI  P6430  RAMA4D_R4      INGLABO  \
# 0          72      6    NaN 1.00   7.00     143.00   790,000.00
# 1          34      6    NaN  NaN    NaN        NaN          NaN
# 2          45      6    NaN 1.00   1.00     141.00 1,100,000.00
# 3          50      6    NaN  NaN    NaN        NaN          NaN
# 4          19      6    NaN 1.00   7.00     141.00   820,000.00
# ...       ...    ...    ...  ...    ...        ...          ...
# 409122     61      6    NaN 1.00   3.00   9,700.00 1,400,000.00
# 409123     58      6   9.00 1.00   2.00   8,530.00 3,000,000.00
# 409124     51      6   9.00 1.00   2.00   8,412.00 7,956,000.00
# 409125     31      6   7.00  NaN    NaN        NaN          NaN
# 409126     26      6   7.00 1.00   4.00   4,791.00   500,000.00
#
#                                          DESCRIPCION_CIIU         NOMBRE_DPTO
# 0                                 Cría de ovejas y cabras           ATLÁNTICO
# 1                                                     NaN           ATLÁNTICO
# 2                        Cría de ganado bovino y bufalino           ATLÁNTICO
# 3                                                     NaN           ATLÁNTICO
# 4                        Cría de ganado bovino y bufalino           ATLÁNTICO
# ...                                                   ...                 ...
# 409122  Actividades de los hogares individuales como e...              TOLIMA
# 409123  Establecimientos que combinan diferentes nivel...  NORTE DE SANTANDER
# 409124  Actividades ejecutivas de la administración pú...  NORTE DE SANTANDER
# 409125                                                NaN  NORTE DE SANTANDER
# 409126  Comercio al por menor realizado a través de in...  NORTE DE SANTANDER
#
# [409127 rows x 18 columns]

# %% [markdown]
# 2. Renombra las columnas del DataFrame `df_empleo` utilizando el diccionario `mapa_nombres`.

# %%
mapa_nombres = {
'DIRECTORIO': 'id_vivienda',
'SECUENCIA_P': 'id_hogar',
'ORDEN': 'id_persona',
'MES': 'mes',
'CLASE': 'clase',
'DPTO': 'departamento',
'FEX_C18': 'factor_expansion',
'PT': 'poblacion_total',
'P3271': 'sexo',
'P6040': 'edad',
'P6080': 'grupo_etnico',
'P3043': 'nivel_educativo',
'OCI': 'ocupados',
'P6430': 'categoria_ocupacional',
'RAMA4D_R4': 'cod_ciiu',
'INGLABO': 'ingreso_laboral',
'DESCRIPCION_CIIU': 'desc_ciiu',
'NOMBRE_DPTO': 'nombre_dpto'}

# %%
df_empleo.rename(columns=mapa_nombres, inplace=True)
df_empleo
# Out:
#         id_vivienda  id_hogar  id_persona  mes  clase  departamento  \
# 0           8283143         1           1    7      2             8
# 1           8283143         1           2    7      2             8
# 2           8283145         1           1    7      2             8
# 3           8283145         1           2    7      2             8
# 4           8283145         1           3    7      2             8
# ...             ...       ...         ...  ...    ...           ...
# 409122      8473907         1           1   12      2            73
# 409123      8473908         1           1   12      1            54
# 409124      8473908         1           2   12      1            54
# 409125      8473908         1           3   12      1            54
# 409126      8473908         1           4   12      1            54
#
#         factor_expansion  poblacion_total  sexo  edad  grupo_etnico  \
# 0                  27.75                1     1    72             6
# 1                  27.75                1     2    34             6
# 2                  59.11                1     1    45             6
# 3                  59.11                1     2    50             6
# 4                  59.11                1     1    19             6
# ...                  ...              ...   ...   ...           ...
# 409122            378.31                1     2    61             6
# 409123            534.55                1     1    58             6
# 409124            534.55                1     2    51             6
# 409125            534.55                1     2    31             6
# 409126            534.55                1     2    26             6
#
#         nivel_educativo  ocupados  categoria_ocupacional  cod_ciiu  \
# 0                   NaN      1.00                   7.00    143.00
# 1                   NaN       NaN                    NaN       NaN
# 2                   NaN      1.00                   1.00    141.00
# 3                   NaN       NaN                    NaN       NaN
# 4                   NaN      1.00                   7.00    141.00
# ...                 ...       ...                    ...       ...
# 409122              NaN      1.00                   3.00  9,700.00
# 409123             9.00      1.00                   2.00  8,530.00
# 409124             9.00      1.00                   2.00  8,412.00
# 409125             7.00       NaN                    NaN       NaN
# 409126             7.00      1.00                   4.00  4,791.00
#
#         ingreso_laboral                                          desc_ciiu  \
# 0            790,000.00                            Cría de ovejas y cabras
# 1                   NaN                                                NaN
# 2          1,100,000.00                   Cría de ganado bovino y bufalino
# 3                   NaN                                                NaN
# 4            820,000.00                   Cría de ganado bovino y bufalino
# ...                 ...                                                ...
# 409122     1,400,000.00  Actividades de los hogares individuales como e...
# 409123     3,000,000.00  Establecimientos que combinan diferentes nivel...
# 409124     7,956,000.00  Actividades ejecutivas de la administración pú...
# 409125              NaN                                                NaN
# 409126       500,000.00  Comercio al por menor realizado a través de in...
#
#                nombre_dpto
# 0                ATLÁNTICO
# 1                ATLÁNTICO
# 2                ATLÁNTICO
# 3                ATLÁNTICO
# 4                ATLÁNTICO
# ...                    ...
# 409122              TOLIMA
# 409123  NORTE DE SANTANDER
# 409124  NORTE DE SANTANDER
# 409125  NORTE DE SANTANDER
# 409126  NORTE DE SANTANDER
#
# [409127 rows x 18 columns]

# %% [markdown]
# 3. Obtenga las dimensiones de la base

# %%
df_empleo.shape
# Out:
# (409127, 18)

# %% [markdown]
# # Ejercicio 3: Revisión de duplicados

# %% [markdown]
# Un paso crucial en la limpieza es asegurar que no haya observaciones duplicadas que puedan sesgar nuestro análisis.

# %% [markdown]
# 1. Verifica si hay filas duplicadas en `df_empleo`.

# %%
df_empleo.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 409122    False
# 409123    False
# 409124    False
# 409125    False
# 409126    False
# Length: 409127, dtype: bool

# %% [markdown]
# 2. Cuenta cuántas filas duplicadas existen.

# %%
df_empleo.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 3. Elimina las filas duplicadas, si las hay.

# %%
df_empleo.drop_duplicates(inplace=True)
df_empleo.shape
# Out:
# (409127, 18)

# %% [markdown]
# 4. Verifica si hay filas duplicadas específicamente en las columnas 'id_vivienda', 'id_hogar', 'id_persona'.

# %%
df_empleo.duplicated(subset=['id_vivienda', 'id_hogar', 'id_persona'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 409122    False
# 409123    False
# 409124    False
# 409125    False
# 409126    False
# Length: 409127, dtype: bool

# %% [markdown]
# # Ejercicio 4: Valores faltantes

# %% [markdown]
# Los datos del mundo real raramente están completos. Aquí, trataremos los valores faltantes en la columna de ingresos.

# %% [markdown]
# 1. Calcula el número de valores nulos (`NaN`) en la columna `ingreso_laboral` **antes** de cualquier modificación.

# %%
df_empleo['ingreso_laboral'].isna().sum()
# Out:
# np.int64(231144)

# %% [markdown]
# 2. En la GEIH, un ingreso faltante a menudo significa que la persona no reportó ingresos o no aplica (ej. no trabaja). Una estrategia común es imputar estos valores con `0`. Rellena los valores `NaN` en la columna `ingreso_laboral` con `0`.

# %%
df_empleo['ingreso_laboral'].fillna(0, inplace=True)
df_empleo
# Out:
#         id_vivienda  id_hogar  id_persona  mes  clase  departamento  \
# 0           8283143         1           1    7      2             8
# 1           8283143         1           2    7      2             8
# 2           8283145         1           1    7      2             8
# 3           8283145         1           2    7      2             8
# 4           8283145         1           3    7      2             8
# ...             ...       ...         ...  ...    ...           ...
# 409122      8473907         1           1   12      2            73
# 409123      8473908         1           1   12      1            54
# 409124      8473908         1           2   12      1            54
# 409125      8473908         1           3   12      1            54
# 409126      8473908         1           4   12      1            54
#
#         factor_expansion  poblacion_total  sexo  edad  grupo_etnico  \
# 0                  27.75                1     1    72             6
# 1                  27.75                1     2    34             6
# 2                  59.11                1     1    45             6
# 3                  59.11                1     2    50             6
# 4                  59.11                1     1    19             6
# ...                  ...              ...   ...   ...           ...
# 409122            378.31                1     2    61             6
# 409123            534.55                1     1    58             6
# 409124            534.55                1     2    51             6
# 409125            534.55                1     2    31             6
# 409126            534.55                1     2    26             6
#
#         nivel_educativo  ocupados  categoria_ocupacional  cod_ciiu  \
# 0                   NaN      1.00                   7.00    143.00
# 1                   NaN       NaN                    NaN       NaN
# 2                   NaN      1.00                   1.00    141.00
# 3                   NaN       NaN                    NaN       NaN
# 4                   NaN      1.00                   7.00    141.00
# ...                 ...       ...                    ...       ...
# 409122              NaN      1.00                   3.00  9,700.00
# 409123             9.00      1.00                   2.00  8,530.00
# 409124             9.00      1.00                   2.00  8,412.00
# 409125             7.00       NaN                    NaN       NaN
# 409126             7.00      1.00                   4.00  4,791.00
#
#         ingreso_laboral                                          desc_ciiu  \
# 0            790,000.00                            Cría de ovejas y cabras
# 1                  0.00                                                NaN
# 2          1,100,000.00                   Cría de ganado bovino y bufalino
# 3                  0.00                                                NaN
# 4            820,000.00                   Cría de ganado bovino y bufalino
# ...                 ...                                                ...
# 409122     1,400,000.00  Actividades de los hogares individuales como e...
# 409123     3,000,000.00  Establecimientos que combinan diferentes nivel...
# 409124     7,956,000.00  Actividades ejecutivas de la administración pú...
# 409125             0.00                                                NaN
# 409126       500,000.00  Comercio al por menor realizado a través de in...
#
#                nombre_dpto
# 0                ATLÁNTICO
# 1                ATLÁNTICO
# 2                ATLÁNTICO
# 3                ATLÁNTICO
# 4                ATLÁNTICO
# ...                    ...
# 409122              TOLIMA
# 409123  NORTE DE SANTANDER
# 409124  NORTE DE SANTANDER
# 409125  NORTE DE SANTANDER
# 409126  NORTE DE SANTANDER
#
# [409127 rows x 18 columns]

# %% [markdown]
# # Ejercicio 5: Decodificar variables

# %% [markdown]
# Las variables categóricas a menudo necesitan ser "traducidas" para hacerlas más entendibles para el análisis.

# %% [markdown]
# 1. Usa los siguientes diccionarios para reemplazar los códigos numéricos por etiquetas de texto en las siguientes columnas: 'clase', 'sexo', 'grupo_etnico', 'nivel_educativo' y 'categoria_ocupacional'. Muestra los conteos de las nuevas categorías usando `.value_counts()` para verificar el cambio en cada una de las columnas.

# %%
dic_clase = {1: 'Cabeceras', 2: 'Centros poblados y rural disperso'}
dic_sexo = {1: 'Hombre', 2: 'Mujer'}
dic_etnico = {1: 'Indígena', 2: 'Gitano (Rom)', 3: 'Raizal del archipiélago', 4: 'Palenquero',
              5: 'Negro, mulato (afrodescendiente)', 6: 'Ninguno de los anteriores'}
dic_nivel_educativo = {1: 'Ninguno', 2: 'Educación media', 3: 'Educación media',
                       4: 'Educación media', 5: 'Técnica profesional', 6: 'Tecnológica',
                       7: 'Universitaria', 8: 'Especialización', 9: 'Maestría',
                       10: 'Doctorado', 99: 'No sabe, no informa'}
dic_cat_ocu = {1: 'Asalariado', 2: 'Asalariado', 3: 'Asalariado',
               8: 'Asalariado', 4: 'Independiente', 5: 'Independiente',
               9: 'Independiente', 6: 'Trabajador sin remuneración',
               7: 'Trabajador sin remuneración'}

# %%
df_empleo['clase'].replace(dic_clase, inplace=True)
df_empleo
# Out:
#         id_vivienda  id_hogar  id_persona  mes  \
# 0           8283143         1           1    7
# 1           8283143         1           2    7
# 2           8283145         1           1    7
# 3           8283145         1           2    7
# 4           8283145         1           3    7
# ...             ...       ...         ...  ...
# 409122      8473907         1           1   12
# 409123      8473908         1           1   12
# 409124      8473908         1           2   12
# 409125      8473908         1           3   12
# 409126      8473908         1           4   12
#
#                                     clase  departamento  factor_expansion  \
# 0       Centros poblados y rural disperso             8             27.75
# 1       Centros poblados y rural disperso             8             27.75
# 2       Centros poblados y rural disperso             8             59.11
# 3       Centros poblados y rural disperso             8             59.11
# 4       Centros poblados y rural disperso             8             59.11
# ...                                   ...           ...               ...
# 409122  Centros poblados y rural disperso            73            378.31
# 409123                          Cabeceras            54            534.55
# 409124                          Cabeceras            54            534.55
# 409125                          Cabeceras            54            534.55
# 409126                          Cabeceras            54            534.55
#
#         poblacion_total  sexo  edad  grupo_etnico  nivel_educativo  ocupados  \
# 0                     1     1    72             6              NaN      1.00
# 1                     1     2    34             6              NaN       NaN
# 2                     1     1    45             6              NaN      1.00
# 3                     1     2    50             6              NaN       NaN
# 4                     1     1    19             6              NaN      1.00
# ...                 ...   ...   ...           ...              ...       ...
# 409122                1     2    61             6              NaN      1.00
# 409123                1     1    58             6             9.00      1.00
# 409124                1     2    51             6             9.00      1.00
# 409125                1     2    31             6             7.00       NaN
# 409126                1     2    26             6             7.00      1.00
#
#         categoria_ocupacional  cod_ciiu  ingreso_laboral  \
# 0                        7.00    143.00       790,000.00
# 1                         NaN       NaN             0.00
# 2                        1.00    141.00     1,100,000.00
# 3                         NaN       NaN             0.00
# 4                        7.00    141.00       820,000.00
# ...                       ...       ...              ...
# 409122                   3.00  9,700.00     1,400,000.00
# 409123                   2.00  8,530.00     3,000,000.00
# 409124                   2.00  8,412.00     7,956,000.00
# 409125                    NaN       NaN             0.00
# 409126                   4.00  4,791.00       500,000.00
#
#                                                 desc_ciiu         nombre_dpto
# 0                                 Cría de ovejas y cabras           ATLÁNTICO
# 1                                                     NaN           ATLÁNTICO
# 2                        Cría de ganado bovino y bufalino           ATLÁNTICO
# 3                                                     NaN           ATLÁNTICO
# 4                        Cría de ganado bovino y bufalino           ATLÁNTICO
# ...                                                   ...                 ...
# 409122  Actividades de los hogares individuales como e...              TOLIMA
# 409123  Establecimientos que combinan diferentes nivel...  NORTE DE SANTANDER
# 409124  Actividades ejecutivas de la administración pú...  NORTE DE SANTANDER
# 409125                                                NaN  NORTE DE SANTANDER
# 409126  Comercio al por menor realizado a través de in...  NORTE DE SANTANDER
#
# [409127 rows x 18 columns]

# %%
df_empleo['sexo'].replace(dic_sexo, inplace=True)
df_empleo
# Out:
#         id_vivienda  id_hogar  id_persona  mes  \
# 0           8283143         1           1    7
# 1           8283143         1           2    7
# 2           8283145         1           1    7
# 3           8283145         1           2    7
# 4           8283145         1           3    7
# ...             ...       ...         ...  ...
# 409122      8473907         1           1   12
# 409123      8473908         1           1   12
# 409124      8473908         1           2   12
# 409125      8473908         1           3   12
# 409126      8473908         1           4   12
#
#                                     clase  departamento  factor_expansion  \
# 0       Centros poblados y rural disperso             8             27.75
# 1       Centros poblados y rural disperso             8             27.75
# 2       Centros poblados y rural disperso             8             59.11
# 3       Centros poblados y rural disperso             8             59.11
# 4       Centros poblados y rural disperso             8             59.11
# ...                                   ...           ...               ...
# 409122  Centros poblados y rural disperso            73            378.31
# 409123                          Cabeceras            54            534.55
# 409124                          Cabeceras            54            534.55
# 409125                          Cabeceras            54            534.55
# 409126                          Cabeceras            54            534.55
#
#         poblacion_total    sexo  edad  grupo_etnico  nivel_educativo  \
# 0                     1  Hombre    72             6              NaN
# 1                     1   Mujer    34             6              NaN
# 2                     1  Hombre    45             6              NaN
# 3                     1   Mujer    50             6              NaN
# 4                     1  Hombre    19             6              NaN
# ...                 ...     ...   ...           ...              ...
# 409122                1   Mujer    61             6              NaN
# 409123                1  Hombre    58             6             9.00
# 409124                1   Mujer    51             6             9.00
# 409125                1   Mujer    31             6             7.00
# 409126                1   Mujer    26             6             7.00
#
#         ocupados  categoria_ocupacional  cod_ciiu  ingreso_laboral  \
# 0           1.00                   7.00    143.00       790,000.00
# 1            NaN                    NaN       NaN             0.00
# 2           1.00                   1.00    141.00     1,100,000.00
# 3            NaN                    NaN       NaN             0.00
# 4           1.00                   7.00    141.00       820,000.00
# ...          ...                    ...       ...              ...
# 409122      1.00                   3.00  9,700.00     1,400,000.00
# 409123      1.00                   2.00  8,530.00     3,000,000.00
# 409124      1.00                   2.00  8,412.00     7,956,000.00
# 409125       NaN                    NaN       NaN             0.00
# 409126      1.00                   4.00  4,791.00       500,000.00
#
#                                                 desc_ciiu         nombre_dpto
# 0                                 Cría de ovejas y cabras           ATLÁNTICO
# 1                                                     NaN           ATLÁNTICO
# 2                        Cría de ganado bovino y bufalino           ATLÁNTICO
# 3                                                     NaN           ATLÁNTICO
# 4                        Cría de ganado bovino y bufalino           ATLÁNTICO
# ...                                                   ...                 ...
# 409122  Actividades de los hogares individuales como e...              TOLIMA
# 409123  Establecimientos que combinan diferentes nivel...  NORTE DE SANTANDER
# 409124  Actividades ejecutivas de la administración pú...  NORTE DE SANTANDER
# 409125                                                NaN  NORTE DE SANTANDER
# 409126  Comercio al por menor realizado a través de in...  NORTE DE SANTANDER
#
# [409127 rows x 18 columns]

# %%
df_empleo['grupo_etnico'].replace(dic_etnico, inplace=True)
df_empleo
# Out:
#         id_vivienda  id_hogar  id_persona  mes  \
# 0           8283143         1           1    7
# 1           8283143         1           2    7
# 2           8283145         1           1    7
# 3           8283145         1           2    7
# 4           8283145         1           3    7
# ...             ...       ...         ...  ...
# 409122      8473907         1           1   12
# 409123      8473908         1           1   12
# 409124      8473908         1           2   12
# 409125      8473908         1           3   12
# 409126      8473908         1           4   12
#
#                                     clase  departamento  factor_expansion  \
# 0       Centros poblados y rural disperso             8             27.75
# 1       Centros poblados y rural disperso             8             27.75
# 2       Centros poblados y rural disperso             8             59.11
# 3       Centros poblados y rural disperso             8             59.11
# 4       Centros poblados y rural disperso             8             59.11
# ...                                   ...           ...               ...
# 409122  Centros poblados y rural disperso            73            378.31
# 409123                          Cabeceras            54            534.55
# 409124                          Cabeceras            54            534.55
# 409125                          Cabeceras            54            534.55
# 409126                          Cabeceras            54            534.55
#
#         poblacion_total    sexo  edad               grupo_etnico  \
# 0                     1  Hombre    72  Ninguno de los anteriores
# 1                     1   Mujer    34  Ninguno de los anteriores
# 2                     1  Hombre    45  Ninguno de los anteriores
# 3                     1   Mujer    50  Ninguno de los anteriores
# 4                     1  Hombre    19  Ninguno de los anteriores
# ...                 ...     ...   ...                        ...
# 409122                1   Mujer    61  Ninguno de los anteriores
# 409123                1  Hombre    58  Ninguno de los anteriores
# 409124                1   Mujer    51  Ninguno de los anteriores
# 409125                1   Mujer    31  Ninguno de los anteriores
# 409126                1   Mujer    26  Ninguno de los anteriores
#
#         nivel_educativo  ocupados  categoria_ocupacional  cod_ciiu  \
# 0                   NaN      1.00                   7.00    143.00
# 1                   NaN       NaN                    NaN       NaN
# 2                   NaN      1.00                   1.00    141.00
# 3                   NaN       NaN                    NaN       NaN
# 4                   NaN      1.00                   7.00    141.00
# ...                 ...       ...                    ...       ...
# 409122              NaN      1.00                   3.00  9,700.00
# 409123             9.00      1.00                   2.00  8,530.00
# 409124             9.00      1.00                   2.00  8,412.00
# 409125             7.00       NaN                    NaN       NaN
# 409126             7.00      1.00                   4.00  4,791.00
#
#         ingreso_laboral                                          desc_ciiu  \
# 0            790,000.00                            Cría de ovejas y cabras
# 1                  0.00                                                NaN
# 2          1,100,000.00                   Cría de ganado bovino y bufalino
# 3                  0.00                                                NaN
# 4            820,000.00                   Cría de ganado bovino y bufalino
# ...                 ...                                                ...
# 409122     1,400,000.00  Actividades de los hogares individuales como e...
# 409123     3,000,000.00  Establecimientos que combinan diferentes nivel...
# 409124     7,956,000.00  Actividades ejecutivas de la administración pú...
# 409125             0.00                                                NaN
# 409126       500,000.00  Comercio al por menor realizado a través de in...
#
#                nombre_dpto
# 0                ATLÁNTICO
# 1                ATLÁNTICO
# 2                ATLÁNTICO
# 3                ATLÁNTICO
# 4                ATLÁNTICO
# ...                    ...
# 409122              TOLIMA
# 409123  NORTE DE SANTANDER
# 409124  NORTE DE SANTANDER
# 409125  NORTE DE SANTANDER
# 409126  NORTE DE SANTANDER
#
# [409127 rows x 18 columns]

# %%
df_empleo['nivel_educativo'].replace(dic_nivel_educativo, inplace=True)
df_empleo
# Out:
#         id_vivienda  id_hogar  id_persona  mes  \
# 0           8283143         1           1    7
# 1           8283143         1           2    7
# 2           8283145         1           1    7
# 3           8283145         1           2    7
# 4           8283145         1           3    7
# ...             ...       ...         ...  ...
# 409122      8473907         1           1   12
# 409123      8473908         1           1   12
# 409124      8473908         1           2   12
# 409125      8473908         1           3   12
# 409126      8473908         1           4   12
#
#                                     clase  departamento  factor_expansion  \
# 0       Centros poblados y rural disperso             8             27.75
# 1       Centros poblados y rural disperso             8             27.75
# 2       Centros poblados y rural disperso             8             59.11
# 3       Centros poblados y rural disperso             8             59.11
# 4       Centros poblados y rural disperso             8             59.11
# ...                                   ...           ...               ...
# 409122  Centros poblados y rural disperso            73            378.31
# 409123                          Cabeceras            54            534.55
# 409124                          Cabeceras            54            534.55
# 409125                          Cabeceras            54            534.55
# 409126                          Cabeceras            54            534.55
#
#         poblacion_total    sexo  edad               grupo_etnico  \
# 0                     1  Hombre    72  Ninguno de los anteriores
# 1                     1   Mujer    34  Ninguno de los anteriores
# 2                     1  Hombre    45  Ninguno de los anteriores
# 3                     1   Mujer    50  Ninguno de los anteriores
# 4                     1  Hombre    19  Ninguno de los anteriores
# ...                 ...     ...   ...                        ...
# 409122                1   Mujer    61  Ninguno de los anteriores
# 409123                1  Hombre    58  Ninguno de los anteriores
# 409124                1   Mujer    51  Ninguno de los anteriores
# 409125                1   Mujer    31  Ninguno de los anteriores
# 409126                1   Mujer    26  Ninguno de los anteriores
#
#        nivel_educativo  ocupados  categoria_ocupacional  cod_ciiu  \
# 0                  NaN      1.00                   7.00    143.00
# 1                  NaN       NaN                    NaN       NaN
# 2                  NaN      1.00                   1.00    141.00
# 3                  NaN       NaN                    NaN       NaN
# 4                  NaN      1.00                   7.00    141.00
# ...                ...       ...                    ...       ...
# 409122             NaN      1.00                   3.00  9,700.00
# 409123        Maestría      1.00                   2.00  8,530.00
# 409124        Maestría      1.00                   2.00  8,412.00
# 409125   Universitaria       NaN                    NaN       NaN
# 409126   Universitaria      1.00                   4.00  4,791.00
#
#         ingreso_laboral                                          desc_ciiu  \
# 0            790,000.00                            Cría de ovejas y cabras
# 1                  0.00                                                NaN
# 2          1,100,000.00                   Cría de ganado bovino y bufalino
# 3                  0.00                                                NaN
# 4            820,000.00                   Cría de ganado bovino y bufalino
# ...                 ...                                                ...
# 409122     1,400,000.00  Actividades de los hogares individuales como e...
# 409123     3,000,000.00  Establecimientos que combinan diferentes nivel...
# 409124     7,956,000.00  Actividades ejecutivas de la administración pú...
# 409125             0.00                                                NaN
# 409126       500,000.00  Comercio al por menor realizado a través de in...
#
#                nombre_dpto
# 0                ATLÁNTICO
# 1                ATLÁNTICO
# 2                ATLÁNTICO
# 3                ATLÁNTICO
# 4                ATLÁNTICO
# ...                    ...
# 409122              TOLIMA
# 409123  NORTE DE SANTANDER
# 409124  NORTE DE SANTANDER
# 409125  NORTE DE SANTANDER
# 409126  NORTE DE SANTANDER
#
# [409127 rows x 18 columns]

# %%
df_empleo['categoria_ocupacional'].replace(dic_cat_ocu, inplace=True)
df_empleo
# Out:
#         id_vivienda  id_hogar  id_persona  mes  \
# 0           8283143         1           1    7
# 1           8283143         1           2    7
# 2           8283145         1           1    7
# 3           8283145         1           2    7
# 4           8283145         1           3    7
# ...             ...       ...         ...  ...
# 409122      8473907         1           1   12
# 409123      8473908         1           1   12
# 409124      8473908         1           2   12
# 409125      8473908         1           3   12
# 409126      8473908         1           4   12
#
#                                     clase  departamento  factor_expansion  \
# 0       Centros poblados y rural disperso             8             27.75
# 1       Centros poblados y rural disperso             8             27.75
# 2       Centros poblados y rural disperso             8             59.11
# 3       Centros poblados y rural disperso             8             59.11
# 4       Centros poblados y rural disperso             8             59.11
# ...                                   ...           ...               ...
# 409122  Centros poblados y rural disperso            73            378.31
# 409123                          Cabeceras            54            534.55
# 409124                          Cabeceras            54            534.55
# 409125                          Cabeceras            54            534.55
# 409126                          Cabeceras            54            534.55
#
#         poblacion_total    sexo  edad               grupo_etnico  \
# 0                     1  Hombre    72  Ninguno de los anteriores
# 1                     1   Mujer    34  Ninguno de los anteriores
# 2                     1  Hombre    45  Ninguno de los anteriores
# 3                     1   Mujer    50  Ninguno de los anteriores
# 4                     1  Hombre    19  Ninguno de los anteriores
# ...                 ...     ...   ...                        ...
# 409122                1   Mujer    61  Ninguno de los anteriores
# 409123                1  Hombre    58  Ninguno de los anteriores
# 409124                1   Mujer    51  Ninguno de los anteriores
# 409125                1   Mujer    31  Ninguno de los anteriores
# 409126                1   Mujer    26  Ninguno de los anteriores
#
#        nivel_educativo  ocupados        categoria_ocupacional  cod_ciiu  \
# 0                  NaN      1.00  Trabajador sin remuneración    143.00
# 1                  NaN       NaN                          NaN       NaN
# 2                  NaN      1.00                   Asalariado    141.00
# 3                  NaN       NaN                          NaN       NaN
# 4                  NaN      1.00  Trabajador sin remuneración    141.00
# ...                ...       ...                          ...       ...
# 409122             NaN      1.00                   Asalariado  9,700.00
# 409123        Maestría      1.00                   Asalariado  8,530.00
# 409124        Maestría      1.00                   Asalariado  8,412.00
# 409125   Universitaria       NaN                          NaN       NaN
# 409126   Universitaria      1.00                Independiente  4,791.00
#
#         ingreso_laboral                                          desc_ciiu  \
# 0            790,000.00                            Cría de ovejas y cabras
# 1                  0.00                                                NaN
# 2          1,100,000.00                   Cría de ganado bovino y bufalino
# 3                  0.00                                                NaN
# 4            820,000.00                   Cría de ganado bovino y bufalino
# ...                 ...                                                ...
# 409122     1,400,000.00  Actividades de los hogares individuales como e...
# 409123     3,000,000.00  Establecimientos que combinan diferentes nivel...
# 409124     7,956,000.00  Actividades ejecutivas de la administración pú...
# 409125             0.00                                                NaN
# 409126       500,000.00  Comercio al por menor realizado a través de in...
#
#                nombre_dpto
# 0                ATLÁNTICO
# 1                ATLÁNTICO
# 2                ATLÁNTICO
# 3                ATLÁNTICO
# 4                ATLÁNTICO
# ...                    ...
# 409122              TOLIMA
# 409123  NORTE DE SANTANDER
# 409124  NORTE DE SANTANDER
# 409125  NORTE DE SANTANDER
# 409126  NORTE DE SANTANDER
#
# [409127 rows x 18 columns]

# %% [markdown]
# # Ejercicio 6: Reorganizar columnas

# %% [markdown]
# 1. Reorganiza las columnas con el siguiente orden: 'id_vivienda', 'id_hogar', 'id_persona', 'mes', 'clase', 'departamento', 'nombre_dpto',     'factor_expansion', 'poblacion_total', 'sexo', 'edad', 'grupo_etnico', 'nivel_educativo', 'ocupados', 'categoria_ocupacional', 'cod_ciiu', 'desc_ciiu', 'ingreso_laboral'

# %%
df_empleo = df_empleo[['id_vivienda', 'id_hogar', 'id_persona', 'mes', 'clase', 'departamento', 'nombre_dpto', 'factor_expansion', 'poblacion_total', 'sexo', 'edad', 'grupo_etnico', 'nivel_educativo', 'ocupados', 'categoria_ocupacional', 'cod_ciiu', 'desc_ciiu', 'ingreso_laboral']]
df_empleo
# Out:
#         id_vivienda  id_hogar  id_persona  mes  clase  departamento  \
# 0           8283143         1           1    7      2             8
# 1           8283143         1           2    7      2             8
# 2           8283145         1           1    7      2             8
# 3           8283145         1           2    7      2             8
# 4           8283145         1           3    7      2             8
# ...             ...       ...         ...  ...    ...           ...
# 409122      8473907         1           1   12      2            73
# 409123      8473908         1           1   12      1            54
# 409124      8473908         1           2   12      1            54
# 409125      8473908         1           3   12      1            54
# 409126      8473908         1           4   12      1            54
#
#                nombre_dpto  factor_expansion  poblacion_total  sexo  edad  \
# 0                ATLÁNTICO             27.75                1     1    72
# 1                ATLÁNTICO             27.75                1     2    34
# 2                ATLÁNTICO             59.11                1     1    45
# 3                ATLÁNTICO             59.11                1     2    50
# 4                ATLÁNTICO             59.11                1     1    19
# ...                    ...               ...              ...   ...   ...
# 409122              TOLIMA            378.31                1     2    61
# 409123  NORTE DE SANTANDER            534.55                1     1    58
# 409124  NORTE DE SANTANDER            534.55                1     2    51
# 409125  NORTE DE SANTANDER            534.55                1     2    31
# 409126  NORTE DE SANTANDER            534.55                1     2    26
#
#         grupo_etnico  nivel_educativo  ocupados  categoria_ocupacional  \
# 0                  6              NaN      1.00                   7.00
# 1                  6              NaN       NaN                    NaN
# 2                  6              NaN      1.00                   1.00
# 3                  6              NaN       NaN                    NaN
# 4                  6              NaN      1.00                   7.00
# ...              ...              ...       ...                    ...
# 409122             6              NaN      1.00                   3.00
# 409123             6             9.00      1.00                   2.00
# 409124             6             9.00      1.00                   2.00
# 409125             6             7.00       NaN                    NaN
# 409126             6             7.00      1.00                   4.00
#
#         cod_ciiu                                          desc_ciiu  \
# 0         143.00                            Cría de ovejas y cabras
# 1            NaN                                                NaN
# 2         141.00                   Cría de ganado bovino y bufalino
# 3            NaN                                                NaN
# 4         141.00                   Cría de ganado bovino y bufalino
# ...          ...                                                ...
# 409122  9,700.00  Actividades de los hogares individuales como e...
# 409123  8,530.00  Establecimientos que combinan diferentes nivel...
# 409124  8,412.00  Actividades ejecutivas de la administración pú...
# 409125       NaN                                                NaN
# 409126  4,791.00  Comercio al por menor realizado a través de in...
#
#         ingreso_laboral
# 0            790,000.00
# 1                   NaN
# 2          1,100,000.00
# 3                   NaN
# 4            820,000.00
# ...                 ...
# 409122     1,400,000.00
# 409123     3,000,000.00
# 409124     7,956,000.00
# 409125              NaN
# 409126       500,000.00
#
# [409127 rows x 18 columns]

# %% [markdown]
# # Ejercicio 7: Cambiar tipo de dato

# %% [markdown]
# Para realizar cálculos y análisis correctamente, las columnas deben tener el tipo de dato adecuado (numérico, categórico, etc.).

# %% [markdown]
# 1.  Muestra en pantalla los tipos de datos actuales de `df_empleo`.

# %%
df_empleo.dtypes
# Out:
# id_vivienda                int64
# id_hogar                   int64
# id_persona                 int64
# mes                        int64
# clase                     object
# departamento               int64
# nombre_dpto               object
# factor_expansion         float64
# poblacion_total            int64
# sexo                      object
# edad                       int64
# grupo_etnico              object
# nivel_educativo           object
# ocupados                 float64
# categoria_ocupacional     object
# cod_ciiu                 float64
# desc_ciiu                 object
# ingreso_laboral          float64
# dtype: object

# %% [markdown]
# 2.  Las siguientes columnas representan categorías: 'clase', 'departamento', 'nombre_dpto', 'sexo', 'grupo_etnico', 'nivel_educativo', 'categoria_ocupacional', 'cod_ciiu', 'desc_ciiu'. Conviértelas al tipo `category` para optimizar el uso de memoria y facilitar análisis futuros.

# %%
df_empleo[['clase', 'departamento', 'nombre_dpto', 'sexo', 'grupo_etnico', 'nivel_educativo', 'categoria_ocupacional', 'cod_ciiu', 'desc_ciiu']] = df_empleo [['clase', 'departamento', 'nombre_dpto', 'sexo', 'grupo_etnico', 'nivel_educativo', 'categoria_ocupacional', 'cod_ciiu', 'desc_ciiu']].astype('category')
df_empleo.dtypes
# Out:
# id_vivienda                 int64
# id_hogar                    int64
# id_persona                  int64
# mes                         int64
# clase                    category
# departamento             category
# nombre_dpto              category
# factor_expansion          float64
# poblacion_total             int64
# sexo                     category
# edad                        int64
# grupo_etnico             category
# nivel_educativo          category
# ocupados                  float64
# categoria_ocupacional    category
# cod_ciiu                 category
# desc_ciiu                category
# ingreso_laboral           float64
# dtype: object

# %% [markdown]
# # Ejercicio 8: Ordenar el dataframe (5%)

# %% [markdown]
# 1. Ordena el dataframe por la columna "edad" de mayor a menor. Observa la columna 'edad' y escribe en una celda de markdown cuál fue la edad mínima y la edad máxima de las personas que respondieron la encuesta de la GEIH.

# %%
df_empleo.sort_values(by='edad', ascending=False)
# Out:
#         id_vivienda  id_hogar  id_persona  mes  \
# 256896      8395695         1           1   10
# 5135        8286476         1           5    7
# 32904       8299104         1           3    7
# 256662      8395585         1           3   10
# 396633      8468208         1           4   12
# ...             ...       ...         ...  ...
# 245532      8391286         1           5   10
# 145507      8348957         1           4    9
# 185317      8365558         1           3    9
# 366733      8446239         1           6   12
# 289156      8409467         1           3   11
#
#                                     clase departamento   nombre_dpto  \
# 256896                          Cabeceras           18       CAQUETÁ
# 5135                            Cabeceras           27         CHOCÓ
# 32904   Centros poblados y rural disperso           13       BOLÍVAR
# 256662                          Cabeceras           17        CALDAS
# 396633  Centros poblados y rural disperso           25  CUNDINAMARCA
# ...                                   ...          ...           ...
# 245532                          Cabeceras           63       QUINDÍO
# 145507                          Cabeceras           50          META
# 185317                          Cabeceras           85      CASANARE
# 366733                          Cabeceras            8     ATLÁNTICO
# 289156                          Cabeceras           27         CHOCÓ
#
#         factor_expansion  poblacion_total    sexo  edad  \
# 256896             40.61                1   Mujer   108
# 5135               31.65                1   Mujer   108
# 32904             128.58                1   Mujer   106
# 256662             66.42                1   Mujer   106
# 396633          1,231.96                1   Mujer   106
# ...                  ...              ...     ...   ...
# 245532            151.42                1   Mujer     0
# 145507            241.71                1  Hombre     0
# 185317            299.88                1   Mujer     0
# 366733          1,371.41                1  Hombre     0
# 289156             52.89                1   Mujer     0
#
#                             grupo_etnico nivel_educativo  ocupados  \
# 256896         Ninguno de los anteriores             NaN       NaN
# 5135    Negro, mulato (afrodescendiente)             NaN       NaN
# 32904   Negro, mulato (afrodescendiente)             NaN       NaN
# 256662         Ninguno de los anteriores             NaN       NaN
# 396633         Ninguno de los anteriores             NaN       NaN
# ...                                  ...             ...       ...
# 245532         Ninguno de los anteriores             NaN       NaN
# 145507         Ninguno de los anteriores             NaN       NaN
# 185317         Ninguno de los anteriores             NaN       NaN
# 366733         Ninguno de los anteriores             NaN       NaN
# 289156  Negro, mulato (afrodescendiente)             NaN       NaN
#
#        categoria_ocupacional cod_ciiu desc_ciiu  ingreso_laboral
# 256896                   NaN      NaN       NaN             0.00
# 5135                     NaN      NaN       NaN             0.00
# 32904                    NaN      NaN       NaN             0.00
# 256662                   NaN      NaN       NaN             0.00
# 396633                   NaN      NaN       NaN             0.00
# ...                      ...      ...       ...              ...
# 245532                   NaN      NaN       NaN             0.00
# 145507                   NaN      NaN       NaN             0.00
# 185317                   NaN      NaN       NaN             0.00
# 366733                   NaN      NaN       NaN             0.00
# 289156                   NaN      NaN       NaN             0.00
#
# [409127 rows x 18 columns]

# %%
edad_min = df_empleo["edad"].min()
edad_max = df_empleo["edad"].max()

edad_min, edad_max
# Out:
# (0, 108)

# %% [markdown]
# La edad mínima de las personas encuestadas es **0 años** y la edad máxima es **108 años**.

# %% [markdown]
# # Ejercicio 9: Groupby

# %% [markdown]
# Agrupar los datos por categorías, nos permite realizar análisis más profundos y obtener insights valiosos, que a simple vista no vemos en la base de datos.

# %% [markdown]
# 1. Crea un nuevo dataframe llamado "df_sexo" donde se agrupe por 'sexo' y se calcule la suma de las columnas 'poblacion_total' y 'ocupados'. Crea una nueva columna que se llame 'porcentaje_ocupados' donde dividas las columna 'ocupados' sobre 'poblacion_total'. Al final usa reset_index() para convertir las categorías de sexo en una columna.

# %%
df_sexo = df_empleo.groupby('sexo')[['poblacion_total', 'ocupados']].sum().reset_index()
df_sexo['porcentaje_ocupados'] = df_sexo['ocupados'] / df_sexo['poblacion_total']
df_sexo
# Out:
#      sexo  poblacion_total   ocupados  porcentaje_ocupados
# 0  Hombre           190530 100,790.00                 0.53
# 1   Mujer           218597  81,063.00                 0.37

# %% [markdown]
# 2. Crea un nuevo dataframe llamado "df_educacion" donde se agrupe por 'nivel_educativo' y se calcule la suma de las columnas 'poblacion_total' y 'ocupados'. Crea una nueva columna que se llame 'porcentaje_ocupados' donde dividas las columna 'ocupados' sobre 'poblacion_total'. Al final usa reset_index() para convertir las categorías de nivel educativo en una columna.

# %%
df_educacion = df_empleo.groupby('nivel_educativo')[['poblacion_total', 'ocupados']].sum().reset_index()
df_educacion['porcentaje_ocupados'] = df_educacion['ocupados'] / df_educacion['poblacion_total']
df_educacion
# Out:
#        nivel_educativo  poblacion_total  ocupados  porcentaje_ocupados
# 0            Doctorado              339    294.00                 0.87
# 1      Educación media           116635 66,945.00                 0.57
# 2      Especialización             7927  6,269.00                 0.79
# 3             Maestría             3154  2,701.00                 0.86
# 4              Ninguno            12963  2,539.00                 0.20
# 5  No sabe, no informa                1      1.00                 1.00
# 6          Tecnológica            10640  7,928.00                 0.75
# 7  Técnica profesional            24503 16,989.00                 0.69
# 8        Universitaria            32517 23,461.00                 0.72

# %% [markdown]
# 3. En una celda de Markdown escribe qué conclusiones puedes sacar de la información obtenida en df_sexo y df_educacion.

# %% [markdown]
# Los datos revelan una brecha de género pronunciada y una fuerte dependencia de la formación académica para acceder al empleo. Mientras que los hombres presentan una tasa de ocupación del 53%, las mujeres, a pesar de ser más numerosas en la población total, solo alcanzan un 37%, lo que evidencia barreras estructurales para la equidad laboral. Paralelamente, la educación actúa como el principal motor de empleabilidad: los niveles de postgrado (Doctorado y Maestría) garantizan tasas de ocupación superiores al 85%, mientras que las personas sin formación académica apenas logran un 20% de inserción. Esta tendencia subraya que, aunque la Educación Media aporta el mayor volumen de trabajadores al mercado, la especialización profesional es el factor determinante para asegurar un puesto de trabajo.
#
# Considerando estos datos, el grupo de Educación Media es el que más personas aporta al total de ocupados (66,945), pero proporcionalmente tiene menos éxito que un profesional universitario. Por otro lado, la diferencia de 16 puntos porcentuales entre hombres y mujeres sugiere que, a pesar de haber más mujeres en la base poblacional, el mercado laboral sigue favoreciendo la contratación masculina.

# %% [markdown]
# # Ejercicio 10: Filtrar datos

# %% [markdown]
# 1. A partir de df_empleo, crea el DataFrame `df_ing` con observaciones donde `ingreso_laboral` no sea nulo y además sea mayor estrictamente al salario mínimo para 2026 (con subsidio de transporte).

# %%
df_ing = df_empleo[df_empleo['ingreso_laboral'].notnull() & (df_empleo['ingreso_laboral'] > 2000000)]
df_ing
# Out:
#         id_vivienda  id_hogar  id_persona  mes  \
# 6           8283147         1           1    7
# 41          8283163         1           1    7
# 111         8283213         1           2    7
# 204         8283275         1           2    7
# 205         8283277         1           1    7
# ...             ...       ...         ...  ...
# 409096      8473895         1           1   12
# 409105      8473898         1           1   12
# 409120      8473904         1           1   12
# 409123      8473908         1           1   12
# 409124      8473908         1           2   12
#
#                                     clase departamento         nombre_dpto  \
# 6       Centros poblados y rural disperso            8           ATLÁNTICO
# 41      Centros poblados y rural disperso            8           ATLÁNTICO
# 111                             Cabeceras           66           RISARALDA
# 204                             Cabeceras           66           RISARALDA
# 205     Centros poblados y rural disperso           66           RISARALDA
# ...                                   ...          ...                 ...
# 409096                          Cabeceras           11        BOGOTÁ, D.C.
# 409105                          Cabeceras           17              CALDAS
# 409120                          Cabeceras           91            AMAZONAS
# 409123                          Cabeceras           54  NORTE DE SANTANDER
# 409124                          Cabeceras           54  NORTE DE SANTANDER
#
#         factor_expansion  poblacion_total    sexo  edad  \
# 6                  57.99                1  Hombre    36
# 41                496.47                1  Hombre    39
# 111               360.58                1  Hombre    24
# 204               208.52                1   Mujer    35
# 205               537.44                1  Hombre    69
# ...                  ...              ...     ...   ...
# 409096          3,528.95                1  Hombre    60
# 409105            275.62                1   Mujer    30
# 409120             64.83                1   Mujer    55
# 409123            534.55                1  Hombre    58
# 409124            534.55                1   Mujer    51
#
#                      grupo_etnico      nivel_educativo  ocupados  \
# 6       Ninguno de los anteriores                  NaN      1.00
# 41      Ninguno de los anteriores          Tecnológica      1.00
# 111     Ninguno de los anteriores        Universitaria      1.00
# 204     Ninguno de los anteriores  Técnica profesional      1.00
# 205     Ninguno de los anteriores      Educación media      1.00
# ...                           ...                  ...       ...
# 409096  Ninguno de los anteriores      Educación media      1.00
# 409105  Ninguno de los anteriores        Universitaria      1.00
# 409120  Ninguno de los anteriores             Maestría      1.00
# 409123  Ninguno de los anteriores             Maestría      1.00
# 409124  Ninguno de los anteriores             Maestría      1.00
#
#        categoria_ocupacional cod_ciiu  \
# 6                 Asalariado 5,022.00
# 41                Asalariado 1,103.00
# 111               Asalariado 8,610.00
# 204               Asalariado 4,631.00
# 205               Asalariado 5,611.00
# ...                      ...      ...
# 409096            Asalariado 4,921.00
# 409105            Asalariado 1,410.00
# 409120            Asalariado 8,551.00
# 409123            Asalariado 8,530.00
# 409124            Asalariado 8,412.00
#
#                                                 desc_ciiu  ingreso_laboral
# 6                             Transporte fluvial de carga     2,623,500.00
# 41      Producción de malta, elaboración de cervezas y...     3,000,000.00
# 111     Actividades de hospitales y clínicas, con inte...     2,700,000.00
# 204       Comercio al por mayor de productos alimenticios     2,200,000.00
# 205              Expendio a la mesa de comidas preparadas     2,450,000.00
# ...                                                   ...              ...
# 409096                            Transporte de pasajeros     2,700,000.00
# 409105  Confección de prendas de vestir, excepto prend...     3,800,000.00
# 409120                          Formación para el trabajo     5,000,000.00
# 409123  Establecimientos que combinan diferentes nivel...     3,000,000.00
# 409124  Actividades ejecutivas de la administración pú...     7,956,000.00
#
# [38093 rows x 18 columns]

# %% [markdown]
# 2. ¿Cuántas personas tienen un salario estrictamente mayor al salario mínimo?

# %%
salario_minimo = 2000000

conteo = (df_ing['ingreso_laboral'] > salario_minimo).sum()

print(conteo)
# Out:
# 38093

# %% [markdown]
# 3. Crea el dataframe df_mujeres donde se encuentren solamente mujeres que están ubicadas en el departamento del Tolima, que son asalariadas y cuyo nivel educativo es educación media o superior.

# %%
niveles_validos = [
    'Educación media',
    'Universitaria',
    'Técnica profesional',
    'Tecnológica',
    'Especialización',
    'Maestría',
    'Doctorado'
]

df_mujeres = df_empleo[
    (df_empleo['sexo'] == 'Mujer') &
    (df_empleo['nombre_dpto'] == 'TOLIMA') &
    (df_empleo['categoria_ocupacional'] == 'Asalariado') &
    (df_empleo['nivel_educativo'].isin(niveles_validos))
]
df_mujeres
# Out:
#         id_vivienda  id_hogar  id_persona  mes  \
# 9253        8289007         1           3    7
# 9269        8289014         1           3    7
# 9272        8289015         1           2    7
# 9286        8289027         1           1    7
# 9287        8289029         1           1    7
# ...             ...       ...         ...  ...
# 409007      8473866         1           1   12
# 409012      8473867         1           2   12
# 409014      8473868         1           2   12
# 409018      8473869         1           2   12
# 409089      8473893         1           2   12
#
#                                     clase departamento nombre_dpto  \
# 9253                            Cabeceras           73      TOLIMA
# 9269                            Cabeceras           73      TOLIMA
# 9272                            Cabeceras           73      TOLIMA
# 9286                            Cabeceras           73      TOLIMA
# 9287                            Cabeceras           73      TOLIMA
# ...                                   ...          ...         ...
# 409007                          Cabeceras           73      TOLIMA
# 409012                          Cabeceras           73      TOLIMA
# 409014                          Cabeceras           73      TOLIMA
# 409018                          Cabeceras           73      TOLIMA
# 409089  Centros poblados y rural disperso           73      TOLIMA
#
#         factor_expansion  poblacion_total   sexo  edad  \
# 9253              240.08                1  Mujer    25
# 9269              130.81                1  Mujer    28
# 9272              221.38                1  Mujer    27
# 9286              240.63                1  Mujer    58
# 9287              285.72                1  Mujer    41
# ...                  ...              ...    ...   ...
# 409007            309.45                1  Mujer    37
# 409012            279.33                1  Mujer    63
# 409014            293.95                1  Mujer    65
# 409018            621.33                1  Mujer    49
# 409089          1,257.14                1  Mujer    29
#
#                      grupo_etnico      nivel_educativo  ocupados  \
# 9253    Ninguno de los anteriores        Universitaria      1.00
# 9269    Ninguno de los anteriores        Universitaria      1.00
# 9272    Ninguno de los anteriores  Técnica profesional      1.00
# 9286    Ninguno de los anteriores  Técnica profesional      1.00
# 9287    Ninguno de los anteriores      Educación media      1.00
# ...                           ...                  ...       ...
# 409007  Ninguno de los anteriores  Técnica profesional      1.00
# 409012  Ninguno de los anteriores        Universitaria      1.00
# 409014  Ninguno de los anteriores        Universitaria      1.00
# 409018  Ninguno de los anteriores      Educación media      1.00
# 409089  Ninguno de los anteriores      Educación media      1.00
#
#        categoria_ocupacional cod_ciiu  \
# 9253              Asalariado 4,321.00
# 9269              Asalariado 8,530.00
# 9272              Asalariado 4,773.00
# 9286              Asalariado 3,600.00
# 9287              Asalariado 5,611.00
# ...                      ...      ...
# 409007            Asalariado 8,530.00
# 409012            Asalariado 8,530.00
# 409014            Asalariado 8,413.00
# 409018            Asalariado 8,121.00
# 409089            Asalariado 5,514.00
#
#                                                 desc_ciiu  ingreso_laboral
# 9253                             Instalaciones eléctricas     3,500,000.00
# 9269    Establecimientos que combinan diferentes nivel...     1,600,000.00
# 9272    Comercio al por menor de productos farmacéutic...     1,423,500.00
# 9286        Captación, tratamiento y distribución de agua     2,000,000.00
# 9287             Expendio a la mesa de comidas preparadas     1,673,000.00
# ...                                                   ...              ...
# 409007  Establecimientos que combinan diferentes nivel...     1,900,000.00
# 409012  Establecimientos que combinan diferentes nivel...     5,500,000.00
# 409014  Regulación de las actividades de organismos qu...     4,000,000.00
# 409018             Limpieza general interior de edificios     1,600,000.00
# 409089                                  Alojamiento rural       800,000.00
#
# [1137 rows x 18 columns]

# %% [markdown]
# 4. ¿Cuáles son las dimensiones de df_mujeres?

# %%
df_mujeres.shape
# Out:
# (1137, 18)
