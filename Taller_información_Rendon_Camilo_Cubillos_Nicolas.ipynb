# %% [markdown]
# **Nombres estudiantes:**
#
# - Camilo Rendón C.
# - Nicolás Cubillos R.

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ### Ejercicio 1:

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Bases'

# %%
# Para establecer el directorio de los archivos
os.chdir(path)

# %%
df_weo = pd.read_excel('Weof.xlsx')
df_weo.head()
# Out:
#   WEO Country Code  ISO WEO Subject Code      Country  \
# 0              512  AFG           NGDP_R  Afghanistan
# 1              512  AFG        NGDP_RPCH  Afghanistan
# 2              512  AFG             NGDP  Afghanistan
# 3              512  AFG            NGDPD  Afghanistan
# 4              512  AFG           PPPGDP  Afghanistan
#
#                         Subject Descriptor  \
# 0  Gross domestic product, constant prices
# 1  Gross domestic product, constant prices
# 2   Gross domestic product, current prices
# 3   Gross domestic product, current prices
# 4   Gross domestic product, current prices
#
#                                        Subject Notes  \
# 0  Expressed in billions of national currency uni...
# 1  Annual percentages of constant price GDP are y...
# 2  Expressed in billions of national currency uni...
# 3  Values are based upon GDP in national currency...
# 4  These data form the basis for the country weig...
#
#                                             Units     Scale  \
# 0                               National currency  Billions
# 1                                  Percent change     Units
# 2                               National currency  Billions
# 3                                    U.S. dollars  Billions
# 4  Purchasing power parity; international dollars  Billions
#
#                        Country/Series-specific Notes 1980  ...       2022  \
# 0  Source: National Statistics Office Latest actu...  NaN  ...  1,032.712
# 1  See notes for:  Gross domestic product, consta...  NaN  ...      -6240
# 2  Source: National Statistics Office Latest actu...  NaN  ...  1,283.442
# 3  See notes for:  Gross domestic product, curren...  NaN  ...      14501
# 4  See notes for:  Gross domestic product, curren...  NaN  ...      86149
#
#         2023 2024 2025 2026 2027 2028 2029 2030 Estimates Start After
# 0  1,056.123  NaN  NaN  NaN  NaN  NaN  NaN  NaN                2024.0
# 1       2267  NaN  NaN  NaN  NaN  NaN  NaN  NaN                2024.0
# 2  1,350.910  NaN  NaN  NaN  NaN  NaN  NaN  NaN                2024.0
# 3      17248  NaN  NaN  NaN  NaN  NaN  NaN  NaN                2024.0
# 4      91272  NaN  NaN  NaN  NaN  NaN  NaN  NaN                2024.0
#
# [5 rows x 61 columns]

# %%
#Últimas 10 filas
df_weo.tail(10)
# Out:
#                                        WEO Country Code  ISO WEO Subject Code  \
# 8616                                                698  ZWE     GGXONLB_NGDP
# 8617                                                698  ZWE           GGXWDN
# 8618                                                698  ZWE      GGXWDN_NGDP
# 8619                                                698  ZWE           GGXWDG
# 8620                                                698  ZWE      GGXWDG_NGDP
# 8621                                                698  ZWE          NGDP_FY
# 8622                                                698  ZWE              BCA
# 8623                                                698  ZWE        BCA_NGDPD
# 8624                                                NaN  NaN              NaN
# 8625  International Monetary Fund, World Economic Ou...  NaN              NaN
#
#        Country                                 Subject Descriptor  \
# 8616  Zimbabwe   General government primary net lending/borrowing
# 8617  Zimbabwe                        General government net debt
# 8618  Zimbabwe                        General government net debt
# 8619  Zimbabwe                      General government gross debt
# 8620  Zimbabwe                      General government gross debt
# 8621  Zimbabwe  Gross domestic product corresponding to fiscal...
# 8622  Zimbabwe                            Current account balance
# 8623  Zimbabwe                            Current account balance
# 8624       NaN                                                NaN
# 8625       NaN                                                NaN
#
#                                           Subject Notes              Units  \
# 8616  Primary net lending/borrowing is net lending (...     Percent of GDP
# 8617  Net debt is calculated as gross debt minus fin...  National currency
# 8618  Net debt is calculated as gross debt minus fin...     Percent of GDP
# 8619  Gross debt consists of all liabilities that re...  National currency
# 8620  Gross debt consists of all liabilities that re...     Percent of GDP
# 8621  Gross domestic product corresponding to fiscal...  National currency
# 8622  Current account is all transactions other than...       U.S. dollars
# 8623  Current account is all transactions other than...     Percent of GDP
# 8624                                                NaN                NaN
# 8625                                                NaN                NaN
#
#          Scale                      Country/Series-specific Notes    1980  \
# 8616     Units  See notes for:  General government primary net...     NaN
# 8617  Billions                                                NaN     NaN
# 8618     Units                                                NaN     NaN
# 8619  Billions  Source: Ministry of Finance or Treasury Latest...     NaN
# 8620     Units  See notes for:  General government gross debt ...     NaN
# 8621  Billions  Source: Ministry of Finance or Treasury Latest...     NaN
# 8622  Billions  Source: Reserve Bank of Zimbabwe and Ministry ...  -0.301
# 8623     Units  See notes for:  Gross domestic product, curren...     NaN
# 8624       NaN                                                NaN     NaN
# 8625       NaN                                                NaN     NaN
#
#       ...   2022   2023    2024       2025       2026       2027       2028  \
# 8616  ...  -4695  -5198   -1096      0.537       1529       1948       2028
# 8617  ...    NaN    NaN     NaN        NaN        NaN        NaN        NaN
# 8618  ...    NaN    NaN     NaN        NaN        NaN        NaN        NaN
# 8619  ...   4935  51682  557793     673344     739670     786902     862793
# 8620  ...  99536  96586   94587      58568      56051      53294      52315
# 8621  ...   4958  53509  589716  1,149.685  1,319.643  1,476.529  1,649.212
# 8622  ...  0.305  0.135   0.505       1143       1210       1198       1226
# 8623  ...  0.935  0.384    1435       2994       3063       2927       2895
# 8624  ...    NaN    NaN     NaN        NaN        NaN        NaN        NaN
# 8625  ...    NaN    NaN     NaN        NaN        NaN        NaN        NaN
#
#            2029       2030 Estimates Start After
# 8616       2108       2108                2024.0
# 8617        NaN        NaN                   NaN
# 8618        NaN        NaN                   NaN
# 8619     930773     993329                2024.0
# 8620      50485      48312                2024.0
# 8621  1,843.656  2,056.061                2024.0
# 8622       1120      0.996                2023.0
# 8623       2554       2196                2023.0
# 8624        NaN        NaN                   NaN
# 8625        NaN        NaN                   NaN
#
# [10 rows x 61 columns]

# %%
#3 Filas aleatorias
df_weo.sample(3)
# Out:
#      WEO Country Code  ISO WEO Subject Code            Country  \
# 2250              469  EGY          NGDPRPC              Egypt
# 1770              634  COG            PPPPC  Republic of Congo
# 7032              733  SSD     GGXONLB_NGDP        South Sudan
#
#                                      Subject Descriptor  \
# 2250  Gross domestic product per capita, constant pr...
# 1770  Gross domestic product per capita, current prices
# 7032   General government primary net lending/borrowing
#
#                                           Subject Notes  \
# 2250  GDP is expressed in constant national currency...
# 1770  Expressed in GDP in PPP dollars per person. Da...
# 7032  Primary net lending/borrowing is net lending (...
#
#                                                Units  Scale  \
# 2250                               National currency  Units
# 1770  Purchasing power parity; international dollars  Units
# 7032                                  Percent of GDP  Units
#
#                           Country/Series-specific Notes        1980  ...  \
# 2250  See notes for:  Gross domestic product, consta...  29,552.436  ...
# 1770  See notes for:  Gross domestic product, curren...   1,622.539  ...
# 7032  See notes for:  General government primary net...         NaN  ...
#
#             2022        2023        2024        2025        2026        2027  \
# 2250  75,699.807  77,351.711  77,654.142  78,991.612  80,763.710  82,974.414
# 1770   6,083.689   6,252.157   6,390.614   6,592.972   6,761.032   6,933.734
# 7032        3426        8897        5202        3589        2557       0.897
#
#             2028        2029        2030 Estimates Start After
# 2250  85,478.802  88,216.384  90,341.906                2023.0
# 1770   7,150.822   7,355.847   7,570.256                2021.0
# 7032      -0.653       -1115       -1430                2024.0
#
# [3 rows x 61 columns]

# %%
#Muestre de la fila 2 a la 5 y solamente la segunda columna
df_weo.iloc[1:5, 1]
# Out:
# 1    AFG
# 2    AFG
# 3    AFG
# 4    AFG
# Name: ISO, dtype: object

# %%
#Use len() para saber cuántas filas tiene
len(df_weo)
# Out:
# 8626

# %%
#Use .shape para saber el número de filas y columnas
df_weo.shape
# Out:
# (8626, 61)

# %%
#Use .columns para ver el nombre de las columnas
df_weo.columns
# Out:
# Index([             'WEO Country Code',                           'ISO',
#                     'WEO Subject Code',                       'Country',
#                   'Subject Descriptor',                 'Subject Notes',
#                                'Units',                         'Scale',
#        'Country/Series-specific Notes',                            1980,
#                                   1981,                            1982,
#                                   1983,                            1984,
#                                   1985,                            1986,
#                                   1987,                            1988,
#                                   1989,                            1990,
#                                   1991,                            1992,
#                                   1993,                            1994,
#                                   1995,                            1996,
#                                   1997,                            1998,
#                                   1999,                            2000,
#                                   2001,                            2002,
#                                   2003,                            2004,
#                                   2005,                            2006,
#                                   2007,                            2008,
#                                   2009,                            2010,
#                                   2011,                            2012,
#                                   2013,                            2014,
#                                   2015,                            2016,
#                                   2017,                            2018,
#                                   2019,                            2020,
#                                   2021,                            2022,
#                                   2023,                            2024,
#                                   2025,                            2026,
#                                   2027,                            2028,
#                                   2029,                            2030,
#                'Estimates Start After'],
#       dtype='object')

# %%
#Use .dtypes para saber el tipo de dato de cada columna
df_weo.dtypes
# Out:
# WEO Country Code          object
# ISO                       object
# WEO Subject Code          object
# Country                   object
# Subject Descriptor        object
#                           ...
# 2027                      object
# 2028                      object
# 2029                      object
# 2030                      object
# Estimates Start After    float64
# Length: 61, dtype: object

# %%
#Use .info() para ver toda la información del conjunto de datos (número de filas, columnas, nombre de columnas, tipos de datos y si hay valores nulos)
df_weo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8626 entries, 0 to 8625
# Data columns (total 61 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   WEO Country Code               8625 non-null   object
#  1   ISO                            8624 non-null   object
#  2   WEO Subject Code               8624 non-null   object
#  3   Country                        8624 non-null   object
#  4   Subject Descriptor             8624 non-null   object
#  5   Subject Notes                  8624 non-null   object
#  6   Units                          8624 non-null   object
#  7   Scale                          8624 non-null   object
#  8   Country/Series-specific Notes  7648 non-null   object
#  9   1980                           3861 non-null   object
#  10  1981                           3995 non-null   object
#  11  1982                           4039 non-null   object
#  12  1983                           4079 non-null   object
#  13  1984                           4104 non-null   object
#  14  1985                           4187 non-null   object
#  15  1986                           4235 non-null   object
#  16  1987                           4259 non-null   object
#  17  1988                           4348 non-null   object
#  18  1989                           4409 non-null   object
#  19  1990                           4889 non-null   object
#  20  1991                           5049 non-null   object
#  21  1992                           5435 non-null   object
#  22  1993                           5635 non-null   object
#  23  1994                           5762 non-null   object
#  24  1995                           6108 non-null   object
#  25  1996                           6242 non-null   object
#  26  1997                           6404 non-null   object
#  27  1998                           6565 non-null   object
#  28  1999                           6659 non-null   object
#  29  2000                           7086 non-null   object
#  30  2001                           7236 non-null   object
#  31  2002                           7329 non-null   object
#  32  2003                           7357 non-null   object
#  33  2004                           7427 non-null   object
#  34  2005                           7460 non-null   object
#  35  2006                           7467 non-null   object
#  36  2007                           7469 non-null   object
#  37  2008                           7478 non-null   object
#  38  2009                           7499 non-null   object
#  39  2010                           7512 non-null   object
#  40  2011                           7517 non-null   object
#  41  2012                           7536 non-null   object
#  42  2013                           7554 non-null   object
#  43  2014                           7578 non-null   object
#  44  2015                           7592 non-null   object
#  45  2016                           7594 non-null   object
#  46  2017                           7599 non-null   object
#  47  2018                           7597 non-null   object
#  48  2019                           7597 non-null   object
#  49  2020                           7560 non-null   object
#  50  2021                           7560 non-null   object
#  51  2022                           7560 non-null   object
#  52  2023                           7557 non-null   object
#  53  2024                           7485 non-null   object
#  54  2025                           7371 non-null   object
#  55  2026                           7371 non-null   object
#  56  2027                           7246 non-null   object
#  57  2028                           7246 non-null   object
#  58  2029                           7246 non-null   object
#  59  2030                           7246 non-null   object
#  60  Estimates Start After          7648 non-null   float64
# dtypes: float64(1), object(60)
# memory usage: 4.0+ MB

# %% [markdown]
# 2. Conectarse a la API del Banco Mundial y traer datos de inflación para Colombia, Ecuador, Brasil, Chile, Mexico y Perú, años 2010-2023

# %%
# !pip install wbdata
# Out:
# Requirement already satisfied: wbdata in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: appdirs<2,>=1.4 in /usr/local/lib/python3.12/dist-packages (from wbdata) (1.4.4)
# Requirement already satisfied: backoff<3,>=2.2.1 in /usr/local/lib/python3.12/dist-packages (from wbdata) (2.2.1)
# Requirement already satisfied: cachetools<6,>=5.3.2 in /usr/local/lib/python3.12/dist-packages (from wbdata) (5.5.2)
# Requirement already satisfied: dateparser<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from wbdata) (1.3.0)
# Requirement already satisfied: decorator<6,>=5.1.1 in /usr/local/lib/python3.12/dist-packages (from wbdata) (5.2.1)
# Requirement already satisfied: requests<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from wbdata) (2.32.4)
# Requirement already satisfied: shelved-cache<0.4,>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from wbdata) (0.3.1)
# Requirement already satisfied: tabulate<1,>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from wbdata) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from dateparser<2,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in /usr/local/lib/python3.12/dist-packages (from dateparser<2,>=1.2.0->wbdata) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from dateparser<2,>=1.2.0->wbdata) (2025.11.3)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.12/dist-packages (from dateparser<2,>=1.2.0->wbdata) (5.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->wbdata) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->wbdata) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->wbdata) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->wbdata) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7.0->dateparser<2,>=1.2.0->wbdata) (1.17.0)

# %%
import wbdata
import datetime
# !pip install wbdata --upgrade
# Out:
# Requirement already satisfied: wbdata in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: appdirs<2,>=1.4 in /usr/local/lib/python3.12/dist-packages (from wbdata) (1.4.4)
# Requirement already satisfied: backoff<3,>=2.2.1 in /usr/local/lib/python3.12/dist-packages (from wbdata) (2.2.1)
# Requirement already satisfied: cachetools<6,>=5.3.2 in /usr/local/lib/python3.12/dist-packages (from wbdata) (5.5.2)
# Requirement already satisfied: dateparser<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from wbdata) (1.3.0)
# Requirement already satisfied: decorator<6,>=5.1.1 in /usr/local/lib/python3.12/dist-packages (from wbdata) (5.2.1)
# Requirement already satisfied: requests<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from wbdata) (2.32.4)
# Requirement already satisfied: shelved-cache<0.4,>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from wbdata) (0.3.1)
# Requirement already satisfied: tabulate<1,>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from wbdata) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from dateparser<2,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in /usr/local/lib/python3.12/dist-packages (from dateparser<2,>=1.2.0->wbdata) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from dateparser<2,>=1.2.0->wbdata) (2025.11.3)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.12/dist-packages (from dateparser<2,>=1.2.0->wbdata) (5.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->wbdata) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->wbdata) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->wbdata) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->wbdata) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7.0->dateparser<2,>=1.2.0->wbdata) (1.17.0)

# %%
wbdata.get_indicators(query="inflation", source=2)
# Out:
# id                    name
# --------------------  -------------------------------------------------
# FP.CPI.TOTL.ZG        Inflation, consumer prices (annual %)
# NY.GDP.DEFL.KD.ZG     Inflation, GDP deflator (annual %)
# NY.GDP.DEFL.KD.ZG.AD  Inflation, GDP deflator: linked series (annual %)

# %%
indicador = {"FP.CPI.TOTL.ZG": "Inflación"}

# El orden es: año (2010), mes (1), día (1)
fecha_inicio = datetime.datetime(2010, 1, 1)
# El orden es: año (2023), mes (1), día (1)
fecha_fin = datetime.datetime(2023, 1, 1)

# Descargar datos
df1 = wbdata.get_dataframe(indicador, country= ["COL","ECU","BRA","CHL","MEX","PER"], date=(fecha_inicio, fecha_fin))

df1
# Out:
#               Inflación
# country date
# Brazil  2023   4.593563
#         2022   9.280106
#         2021   8.301660
#         2020   3.211768
#         2019   3.732976
# ...                 ...
# Peru    2014   3.411946
#         2013   2.767897
#         2012   3.611213
#         2011   3.369311
#         2010   1.528321
#
# [84 rows x 1 columns]

# %%
#Primeras 5 filas
df1.head()
# Out:
#               Inflación
# country date
# Brazil  2023   4.593563
#         2022   9.280106
#         2021   8.301660
#         2020   3.211768
#         2019   3.732976

# %%
#Últimas 10 filas
df1.tail(10)
# Out:
#               Inflación
# country date
# Peru    2019   2.252122
#         2018   1.509154
#         2017   2.994900
#         2016   3.557177
#         2015   3.398092
#         2014   3.411946
#         2013   2.767897
#         2012   3.611213
#         2011   3.369311
#         2010   1.528321

# %%
#3 Filas aleatorias
df1.sample(3)
# Out:
#                Inflación
# country  date
# Peru     2017   2.994900
# Mexico   2017   6.041457
# Colombia 2013   2.016992

# %%
#Muestre de la fila 2 a la 5 y solamente la segunda columna
df1.iloc[1:5, 0]
#El df solo tiene una columna, lo podemos ver con .shape, es por esto que se usa 0 para mostrar la única que hay. Si se intenta mostrar la segunda columa arroja un error
# Out:
# country  date
# Brazil   2022    9.280106
#          2021    8.301660
#          2020    3.211768
#          2019    3.732976
# Name: Inflación, dtype: float64

# %%
#Use len() para saber cuantas filas tiene
len(df1)
# Out:
# 84

# %%
#Use .shape para saber el número de filas y columnas
df1.shape
# Out:
# (84, 1)

# %%
#Use .columns para ver el nombre de las columnas
df1.columns
# Out:
# Index(['Inflación'], dtype='object')

# %%
#Use dtypes para saver el tipo de dato de cada columna
df1.dtypes
# Out:
# Inflación    float64
# dtype: object

# %%
#Use .info() para ver toda la información del conjunto de datos (número de filas, columnas, nombre de columnas, tipos de datos y si hay valores nulos)
df1.info()
# Out:
# <class 'wbdata.client.DataFrame'>
# MultiIndex: 84 entries, ('Brazil', '2023') to ('Peru', '2010')
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Inflación  84 non-null     float64
# dtypes: float64(1)
# memory usage: 1.8+ KB

# %% [markdown]
# 3. Conectarse a la API del Banco Mundial y traer los siguientes datos para Alemania 2010-2023: crecimiento del PIB, PIB per cápita, tasa de inflación, tasa de desempleo y población.

# %%
indicador = {"NY.GDP.MKTP.KD.ZG": "Crecimiento del PIB","NY.GDP.PCAP.PP.CD": "PIB per cápita en PPA","FP.CPI.TOTL.ZG": "Tasa de inflación", "SL.UEM.TOTL.ZS":"Desempleo","SP.POP.TOTL":"Población"}

# El orden es: año (2010), mes (1), día (1)
fecha_inicio = datetime.datetime(2010, 1, 1)
# El orden es: año (2023), mes (1), día (1)
fecha_fin = datetime.datetime(2023, 1, 1)

# Descargar datos
df2 = wbdata.get_dataframe(indicador, country= ["DEU"], date=(fecha_inicio, fecha_fin))

df2
# Out:
# 2020    58685.872700
# 2019    59270.727650
# Name: PIB per cápita en PPA, dtype: float64

# %%
#Use .len() para saber cuantas filas tiene
len(df2)
# Out:
# 14

# %%
#Use .shape para saber el numero de filas y columnas
df2.shape
# Out:
# (14, 5)

# %%
#Use .columns para ver el nombre de las columnas
df2.columns
# Out:
# Index(['Crecimiento del PIB', 'PIB per cápita en PPA', 'Tasa de inflación',
#        'Desempleo', 'Población'],
#       dtype='object')

# %%
#Use .dtypes para saber el tipo de dato de cada columna
df2.dtypes
# Out:
# Crecimiento del PIB      float64
# PIB per cápita en PPA    float64
# Tasa de inflación        float64
# Desempleo                float64
# Población                float64
# dtype: object

# %%
#Use .info() para ver toda la información del conjunto de datos (número de filas, columnas, nombre de columnas, tipos de datos y si hay valores nulos)
df2.info()
# Out:
# <class 'wbdata.client.DataFrame'>
# Index: 14 entries, 2023 to 2010
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Crecimiento del PIB    14 non-null     float64
#  1   PIB per cápita en PPA  14 non-null     float64
#  2   Tasa de inflación      14 non-null     float64
#  3   Desempleo              14 non-null     float64
#  4   Población              14 non-null     float64
# dtypes: float64(5)
# memory usage: 672.0+ bytes

# %% [markdown]
# 4. Traer dos conjuntos de datos de la página de datos abiertos del Gobierno de Colombia usando API. Los que le llamen la atención

# %%
import requests

# %%
url = "https://www.datos.gov.co/resource/2a76-5evx.json"

# Solicitud a la API
response = requests.get(url)
data = response.json()

# Convertir a DataFrame
df3 = pd.DataFrame(data)

df3.head()
# Out:
#     ano cod_etc    nombre_etc
# 0  2021    3819  Buenaventura
# 1  2020    3819  Buenaventura
# 2  2019    3819  Buenaventura
# 3  2018    3819  Buenaventura
# 4  2017    3819  Buenaventura

# %%
#Primeras 5 filas
df3.head()
# Out:
#     ano cod_etc    nombre_etc
# 0  2021    3819  Buenaventura
# 1  2020    3819  Buenaventura
# 2  2019    3819  Buenaventura
# 3  2018    3819  Buenaventura
# 4  2017    3819  Buenaventura

# %%
#Últimas 10 filas
df3.tail(10)
# Out:
#      ano cod_etc    nombre_etc
# 4   2017    3819  Buenaventura
# 5   2016    3819  Buenaventura
# 6   2015    3819  Buenaventura
# 7   2014    3819  Buenaventura
# 8   2013    3819  Buenaventura
# 9   2012    3819  Buenaventura
# 10  2011    3819  Buenaventura
# 11  2022    3819  Buenaventura
# 12  2023    3819  Buenaventura
# 13  2024    3819  Buenaventura

# %%
#3 filas aleatorias
df3.sample(3)
# Out:
#     ano cod_etc    nombre_etc
# 9  2012    3819  Buenaventura
# 8  2013    3819  Buenaventura
# 6  2015    3819  Buenaventura

# %%
#Muestre la fila 2 a la 5 y solamente la segunda columna
df3.iloc[2:6,1]
# Out:
# 2    3819
# 3    3819
# 4    3819
# 5    3819
# Name: cod_etc, dtype: object

# %%
#Use .len() para saber cuantas filas tiene
len(df3)
# Out:
# 14

# %%
#Use .shape para saber el numero de filas y columnas
df3.shape
# Out:
# (14, 3)

# %%
#Use .columns para ver el nombre de las columnas
df3.columns
# Out:
# Index(['ano', 'cod_etc', 'nombre_etc'], dtype='object')

# %%
#Use .dtypes para saber el tipo de dato de cada columna
df3.dtypes
# Out:
# ano           object
# cod_etc       object
# nombre_etc    object
# dtype: object

# %%
#Use .info() para ver toda la información del conjunto de datos (número de filas, columnas, nombre de columnas, tipos de datos y si hay valores nulos)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ano         14 non-null     object
#  1   cod_etc     14 non-null     object
#  2   nombre_etc  14 non-null     object
# dtypes: object(3)
# memory usage: 468.0+ bytes

# %%
link = "https://www.datos.gov.co/resource/6z97-i2yt.json"

# Solicitud a la API
response = requests.get(link)
data = response.json()

# Convertir a DataFrame
df4 = pd.DataFrame(data)

df4.head()
# Out:
#   vigencia mes              rubro                                  concepto  \
# 0     2025   7                  0                    DISPONIBILIDAD INICIAL
# 1     2025   7  1-02-5-01-03-05-4                 PRODUCTOS QUÍMICOS N.C.P.
# 2     2025   7  1-02-5-01-04-01-2               PRODUCTOS DE HIERRO Y ACERO
# 3     2025   7  1-02-5-01-04-04-7  ARMAS Y MUNICIONES Y SUS PARTES Y PIEZAS
# 4     2025   7  1-02-5-01-05-04-6                SERVICIOS DE INSTALACIONES
#
#   presupuesto_vigente_pv   recaudos_rs    rs_pv
# 0           254497000000  160598462957   6310.0
# 1           773998900000  287869623233  3719.00
# 2             5824000000    2011507282  3454.00
# 3           246663000000  107113202118  4342.00
# 4             1407000000        137499     1.00

# %%
#Primeras 5 filas
df4.head()
# Out:
#   vigencia mes              rubro                                  concepto  \
# 0     2025   7                  0                    DISPONIBILIDAD INICIAL
# 1     2025   7  1-02-5-01-03-05-4                 PRODUCTOS QUÍMICOS N.C.P.
# 2     2025   7  1-02-5-01-04-01-2               PRODUCTOS DE HIERRO Y ACERO
# 3     2025   7  1-02-5-01-04-04-7  ARMAS Y MUNICIONES Y SUS PARTES Y PIEZAS
# 4     2025   7  1-02-5-01-05-04-6                SERVICIOS DE INSTALACIONES
#
#   presupuesto_vigente_pv   recaudos_rs    rs_pv
# 0           254497000000  160598462957   6310.0
# 1           773998900000  287869623233  3719.00
# 2             5824000000    2011507282  3454.00
# 3           246663000000  107113202118  4342.00
# 4             1407000000        137499     1.00

# %%
#Últimas 10 filas
df4.tail(10)
# Out:
#    vigencia mes              rubro                                  concepto  \
# 38     2025  11          2-05-1-03              VALORES DISTINTOS A ACCIONES
# 39     2025  11          2-15-1-03                         DE OTRAS EMPRESAS
# 40     2025  12                  0                    DISPONIBILIDAD INICIAL
# 41     2025  12  1-02-5-01-03-05-4                 PRODUCTOS QUÍMICOS N.C.P.
# 42     2025  12  1-02-5-01-04-01-2               PRODUCTOS DE HIERRO Y ACERO
# 43     2025  12  1-02-5-01-04-04-7  ARMAS Y MUNICIONES Y SUS PARTES Y PIEZAS
# 44     2025  12  1-02-5-01-05-04-6                SERVICIOS DE INSTALACIONES
# 45     2025  12  1-02-5-01-08-08-9            OTROS SERVICIOS DE FABRICACIÓN
# 46     2025  12          2-05-1-03              VALORES DISTINTOS A ACCIONES
# 47     2025  12          2-15-1-03                         DE OTRAS EMPRESAS
#
#    presupuesto_vigente_pv   recaudos_rs     rs_pv
# 38            20000000000   28734528549  14367.00
# 39             6978200000    6723724786   9635.00
# 40           254497000000  160598462957    6310.0
# 41           773998900000  606586600947   7837.00
# 42             5824000000    4994245543   8575.00
# 43           246663000000  134595048511   5457.00
# 44             1407000000        283715      2.00
# 45            17710100000   21747260922   12280.0
# 46            20000000000   31621852985  15811.00
# 47             6978200000    7374001150  10567.00

# %%
#3 filas aleatorias
df4.sample(3)
# Out:
#    vigencia mes              rubro                                  concepto  \
# 27     2025  10  1-02-5-01-04-04-7  ARMAS Y MUNICIONES Y SUS PARTES Y PIEZAS
# 18     2025   9  1-02-5-01-04-01-2               PRODUCTOS DE HIERRO Y ACERO
# 11     2025   8  1-02-5-01-04-04-7  ARMAS Y MUNICIONES Y SUS PARTES Y PIEZAS
#
#    presupuesto_vigente_pv   recaudos_rs    rs_pv
# 27           246663000000  143258284735  5808.00
# 18             5824000000    4649918703  7984.00
# 11           246663000000  138753807902  5625.00

# %%
#Muestre la fila 2 a la 5 y solamente la segunda columna
df4.iloc[2:6,1]
# Out:
# 2    7
# 3    7
# 4    7
# 5    7
# Name: mes, dtype: object

# %%
#Use .len() para saber cuantas filas tiene
len(df4)
# Out:
# 48

# %%
#Use .shape para saber el numero de filas y columnas
df4.shape
# Out:
# (48, 7)

# %%
#Use .columns para ver el nombre de las columnas
df4.columns
# Out:
# Index(['vigencia', 'mes', 'rubro', 'concepto', 'presupuesto_vigente_pv',
#        'recaudos_rs', 'rs_pv'],
#       dtype='object')

# %%
#Use .dtypes para saber el tipo de dato de cada columna
df4.dtypes
# Out:
# vigencia                  object
# mes                       object
# rubro                     object
# concepto                  object
# presupuesto_vigente_pv    object
# recaudos_rs               object
# rs_pv                     object
# dtype: object

# %%
#Use .info() para ver toda la información del conjunto de datos (número de filas, columnas, nombre de columnas, tipos de datos y si hay valores nulos)
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   vigencia                48 non-null     object
#  1   mes                     48 non-null     object
#  2   rubro                   48 non-null     object
#  3   concepto                48 non-null     object
#  4   presupuesto_vigente_pv  48 non-null     object
#  5   recaudos_rs             48 non-null     object
#  6   rs_pv                   48 non-null     object
# dtypes: object(7)
# memory usage: 2.8+ KB

# %%
url = "https://api.coingecko.com/api/v3/coins/markets"
params = {
    'vs_currency': 'usd',
    'order': 'market_cap_desc',
    'per_page': 40,
    'page': 2
}

response = requests.get(url, params=params)
df5= pd.DataFrame(response.json())
df5
# Out:
#                                                    id  symbol  \
# 0                                                 okb     okb
# 1   blackrock-usd-institutional-digital-liquidity-...   buidl
# 2                                       hashnote-usyc    usyc
# 3                                          pi-network      pi
# 4                                           bittensor     tao
# 5                                                aave    aave
# 6                                                 sky     sky
# 7                                      falcon-finance    usdf
# 8                                             aster-2   aster
# 9                                       global-dollar    usdg
# 10                                               near    near
# 11                                         ripple-usd   rlusd
# 12                                       bitget-token     bgb
# 13                                            htx-dao     htx
# 14                                               pepe    pepe
# 15                                  internet-computer     icp
# 16                                   ethereum-classic     etc
# 17                                              bfusd   bfusd
# 18                                       ondo-finance    ondo
# 19                                           pump-fun    pump
# 20                                      worldcoin-wld     wld
# 21                                    gatechain-token      gt
# 22                            polygon-ecosystem-token     pol
# 23                                             morpho  morpho
# 24                                      kucoin-shares     kcs
# 25  superstate-short-duration-us-government-securi...    ustb
# 26                                         midnight-3   night
# 27                                      quant-network     qnt
# 28                                             ethena     ena
# 29                               ondo-us-dollar-yield    usdy
# 30                                             cosmos    atom
# 31                                               nexo    nexo
# 32                                              eutbl   eutbl
# 33                                              usdtb   usdtb
# 34                                              kaspa     kas
# 35                                     flare-networks     flr
# 36                                              aptos     apt
# 37                                           algorand    algo
# 38                                           filecoin     fil
# 39                                     official-trump   trump
#
#                                                  name  \
# 0                                                 OKB
# 1   BlackRock USD Institutional Digital Liquidity ...
# 2                                         Circle USYC
# 3                                          Pi Network
# 4                                           Bittensor
# 5                                                Aave
# 6                                                 Sky
# 7                                          Falcon USD
# 8                                               Aster
# 9                                       Global Dollar
# 10                                      NEAR Protocol
# 11                                         Ripple USD
# 12                                       Bitget Token
# 13                                            HTX DAO
# 14                                               Pepe
# 15                                  Internet Computer
# 16                                   Ethereum Classic
# 17                                              BFUSD
# 18                                               Ondo
# 19                                           Pump.fun
# 20                                          Worldcoin
# 21                                               Gate
# 22                                     POL (ex-MATIC)
# 23                                             Morpho
# 24                                             KuCoin
# 25  Superstate Short Duration U.S. Government Secu...
# 26                                           Midnight
# 27                                              Quant
# 28                                             Ethena
# 29                               Ondo US Dollar Yield
# 30                                         Cosmos Hub
# 31                                               NEXO
# 32                 Spiko EU T-Bills Money Market Fund
# 33                                              USDtb
# 34                                              Kaspa
# 35                                              Flare
# 36                                              Aptos
# 37                                           Algorand
# 38                                           Filecoin
# 39                                     Official Trump
#
#                                                 image  current_price  \
# 0   https://coin-images.coingecko.com/coins/images...      95.740000
# 1   https://coin-images.coingecko.com/coins/images...       1.000000
# 2   https://coin-images.coingecko.com/coins/images...       1.120000
# 3   https://coin-images.coingecko.com/coins/images...       0.202813
# 4   https://coin-images.coingecko.com/coins/images...     189.450000
# 5   https://coin-images.coingecko.com/coins/images...     117.920000
# 6   https://coin-images.coingecko.com/coins/images...       0.076375
# 7   https://coin-images.coingecko.com/coins/images...       0.997599
# 8   https://coin-images.coingecko.com/coins/images...       0.706269
# 9   https://coin-images.coingecko.com/coins/images...       0.999831
# 10  https://coin-images.coingecko.com/coins/images...       1.280000
# 11  https://coin-images.coingecko.com/coins/images...       0.999927
# 12  https://coin-images.coingecko.com/coins/images...       2.210000
# 13  https://coin-images.coingecko.com/coins/images...       0.000002
# 14  https://coin-images.coingecko.com/coins/images...       0.000003
# 15  https://coin-images.coingecko.com/coins/images...       2.550000
# 16  https://coin-images.coingecko.com/coins/images...       8.700000
# 17  https://coin-images.coingecko.com/coins/images...       0.999202
# 18  https://coin-images.coingecko.com/coins/images...       0.268137
# 19  https://coin-images.coingecko.com/coins/images...       0.002010
# 20  https://coin-images.coingecko.com/coins/images...       0.407581
# 36  2026-03-06T03:09:12.674Z
# 37  2026-03-06T03:09:12.193Z
# 38  2026-03-06T03:09:12.672Z
# 39  2026-03-06T03:09:12.054Z
#
# [40 rows x 26 columns]

# %%
#Primeras 5 filas
df5.head()
# Out:
#                                                   id symbol  \
# 0                                                okb    okb
# 1  blackrock-usd-institutional-digital-liquidity-...  buidl
# 2                                      hashnote-usyc   usyc
# 3                                         pi-network     pi
# 4                                          bittensor    tao
#
#                                                 name  \
# 0                                                OKB
# 1  BlackRock USD Institutional Digital Liquidity ...
# 2                                        Circle USYC
# 3                                         Pi Network
# 4                                          Bittensor
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...      95.740000
# 1  https://coin-images.coingecko.com/coins/images...       1.000000
# 2  https://coin-images.coingecko.com/coins/images...       1.120000
# 3  https://coin-images.coingecko.com/coins/images...       0.202813
# 4  https://coin-images.coingecko.com/coins/images...     189.450000
#
#    market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  2010473145               41               2010473145   399691127.0
# 1  2006635146               42               2006635146           0.0
# 2  1946565991               43               1946565991       55935.0
# 3  1937361568               44               2980556258    51120060.0
# 4  1818862128               45               3979801042   104315952.0
#
#     high_24h  ...  total_supply    max_supply     ath  ath_change_percentage  \
# 0  117.60000  ...  2.100000e+07  2.100000e+07  255.50              -61.97148
# 1    1.00000  ...  2.006635e+09           NaN    1.00                0.00000
# 2        NaN  ...  1.740028e+09           NaN    1.12               -0.00027
# 3    0.20307  ...  1.471117e+10  1.000000e+11    2.99              -93.25536
# 4  193.42000  ...  2.100000e+07  2.100000e+07  757.60              -74.98873
#
#                    ath_date        atl  atl_change_percentage  \
# 0  2025-08-22T01:50:26.131Z   0.580608            16634.83052
# 1  2025-02-12T05:00:10.912Z   1.000000                0.00000
# 2  2026-03-04T11:11:25.534Z   1.026000                9.02399
# 3  2025-02-26T16:41:03.732Z   0.131244               53.53381
# 4  2024-03-07T18:45:36.466Z  30.830000              514.61835
#
#                    atl_date   roi              last_updated
# 0  2019-01-14T00:00:00.000Z  None  2026-03-06T03:09:11.899Z
# 1  2025-02-12T05:45:10.196Z  None  2026-03-06T03:05:08.212Z
# 2  2024-12-05T22:31:20.475Z  None  2026-03-05T00:43:04.053Z
# 3  2026-02-11T17:06:46.605Z  None  2026-03-06T03:09:11.669Z
# 4  2023-05-14T08:57:53.732Z  None  2026-03-06T03:09:11.981Z
#
# [5 rows x 26 columns]

# %%
#Últimas 10 filas
df5.tail(10)
# Out:
#                 id symbol                                name  \
# 30          cosmos   atom                          Cosmos Hub
# 31            nexo   nexo                                NEXO
# 32           eutbl  eutbl  Spiko EU T-Bills Money Market Fund
# 33           usdtb  usdtb                               USDtb
# 34           kaspa    kas                               Kaspa
# 35  flare-networks    flr                               Flare
# 36           aptos    apt                               Aptos
# 37        algorand   algo                            Algorand
# 38        filecoin    fil                            Filecoin
# 39  official-trump  trump                      Official Trump
#
#                                                 image  current_price  \
# 30  https://coin-images.coingecko.com/coins/images...       1.850000
# 31  https://coin-images.coingecko.com/coins/images...       0.896909
# 32  https://coin-images.coingecko.com/coins/images...       1.220000
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37  {'times': -0.9634758619902654, 'currency': 'us...
# 38                                               None
# 39                                               None
#
#                 last_updated
# 30  2026-03-06T03:09:12.682Z
# 31  2026-03-06T03:09:11.865Z
# 32  2026-03-06T03:05:09.155Z
# 33  2026-03-06T03:09:11.895Z
# 34  2026-03-06T03:09:13.618Z
# 35  2026-03-06T03:09:11.872Z
# 36  2026-03-06T03:09:12.674Z
# 37  2026-03-06T03:09:12.193Z
# 38  2026-03-06T03:09:12.672Z
# 39  2026-03-06T03:09:12.054Z
#
# [10 rows x 26 columns]

# %%
#Muestre la fila 2 a la 5 y solamente la segunda columna
df5.iloc[1:5, 1]
# Out:
# 1    buidl
# 2     usyc
# 3       pi
# 4      tao
# Name: symbol, dtype: object

# %%
#Use .len() para saber cuantas filas tiene
len(df5)
# Out:
# 40

# %%
#Use .shape para saber el numero de filas y columnas
df5.shape
# Out:
# (40, 26)

# %%
#Use .columns para ver el nombre de las columnas
df5.columns
# Out:
# Index(['id', 'symbol', 'name', 'image', 'current_price', 'market_cap',
#        'market_cap_rank', 'fully_diluted_valuation', 'total_volume',
#        'high_24h', 'low_24h', 'price_change_24h',
#        'price_change_percentage_24h', 'market_cap_change_24h',
#        'market_cap_change_percentage_24h', 'circulating_supply',
#        'total_supply', 'max_supply', 'ath', 'ath_change_percentage',
#        'ath_date', 'atl', 'atl_change_percentage', 'atl_date', 'roi',
#        'last_updated'],
#       dtype='object')

# %%
#Use .dtypes para saber el tipo de dato de cada columna
df5.dtypes
# Out:
# id                                   object
# symbol                               object
# name                                 object
# image                                object
# current_price                       float64
# market_cap                            int64
# market_cap_rank                       int64
# fully_diluted_valuation               int64
# total_volume                        float64
# high_24h                            float64
# low_24h                             float64
# price_change_24h                    float64
# price_change_percentage_24h         float64
# market_cap_change_24h               float64
# market_cap_change_percentage_24h    float64
# circulating_supply                  float64
# total_supply                        float64
# max_supply                          float64
# ath                                 float64
# ath_change_percentage               float64
# ath_date                             object
# atl                                 float64
# atl_change_percentage               float64
# atl_date                             object
# roi                                  object
# last_updated                         object
# dtype: object

# %%
#Use .info() para ver toda la información del conjunto de datos (número de filas, columnas, nombre de columnas, tipos de datos y si hay valores nulos)
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                40 non-null     object
#  1   symbol                            40 non-null     object
#  2   name                              40 non-null     object
#  3   image                             40 non-null     object
#  4   current_price                     40 non-null     float64
#  5   market_cap                        40 non-null     int64
#  6   market_cap_rank                   40 non-null     int64
#  7   fully_diluted_valuation           40 non-null     int64
#  8   total_volume                      40 non-null     float64
#  9   high_24h                          39 non-null     float64
#  10  low_24h                           39 non-null     float64
#  11  price_change_24h                  39 non-null     float64
#  12  price_change_percentage_24h       39 non-null     float64
#  13  market_cap_change_24h             39 non-null     float64
#  14  market_cap_change_percentage_24h  39 non-null     float64
#  15  circulating_supply                40 non-null     float64
#  16  total_supply                      40 non-null     float64
#  17  max_supply                        22 non-null     float64
#  18  ath                               40 non-null     float64
#  19  ath_change_percentage             40 non-null     float64
#  20  ath_date                          40 non-null     object
#  21  atl                               40 non-null     float64
#  22  atl_change_percentage             40 non-null     float64
#  23  atl_date                          40 non-null     object
#  24  roi                               5 non-null      object
#  25  last_updated                      40 non-null     object
# dtypes: float64(15), int64(3), object(8)
# memory usage: 8.3+ KB
